# %% [markdown]
# ---
# comments: true
# layout: post
# title: Passion Project Frontend
# description: Our frontend code for our passion project!
# type: hacks
# courses: { compsci: {week: 2} }
# ---

# %%
# %%html
# <html>
# <head>
#     <title>Cancer Data App</title>
# </head>
# <body>
#     <h1>Cancer Data</h1>
#     <p>Click the button to retrieve data from the backend:</p>
#     <button id="getDataButton">Get Data</button>
#     <div id="dataDisplay"></div>
#
#     <script>
#         document.getElementById("getDataButton").addEventListener("click", function() {
#             fetch('/api/data')
#                 .then(response => response.json())
#                 .then(data => {
#                     let dataDisplay = document.getElementById('dataDisplay');
#                     dataDisplay.innerHTML = '';  // Clear any previous data
#
#                     data.forEach(item => {
#                         let itemDiv = document.createElement('div');
#                         itemDiv.textContent = JSON.stringify(item);
#                         dataDisplay.appendChild(itemDiv);
#                     });
#                 })
#                 .catch(error => {
#                     console.error('Error fetching data:', error);
#                 });
#         });
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <title>Cancer Data App</title>
# </head>
# <body>
#     <h1>Cancer Data</h1>
#     <p>Click the button to retrieve data from the backend:</p>
#     <button id="getDataButton">Get Data</button>
#     <div id="dataDisplay"></div>
#
#     <script>
#         document.getElementById("getDataButton").addEventListener("click", function() {
#             fetch('/api/data')
#                 .then(response => response.json())
#                 .then(data => {
#                     let dataDisplay = document.getElementById('dataDisplay');
#                     dataDisplay.innerHTML = '';  // Clear any previous data
#
#                     data.forEach(item => {
#                         let itemDiv = document.createElement('div');
#                         itemDiv.textContent = JSON.stringify(item);
#                         dataDisplay.appendChild(itemDiv);
#                     });
#                 })
#                 .catch(error => {
# ...

# %%
# %%html
# <body>
#
# <h1>Did you know that climate change causes lung cancer?</h1>
# <p>It's surprising that according to the American Lung Association, rising temperatures, wildfires and poor air quality all lead to an increase in the prevalence of lung cancer.</p>
#
# <h1> But what can you do to solve this issue? </h1>
#
# <h1> Let's start with a quiz about lung cancer. See how much you know!</h1>
#
# </body>
# </html>
# Out:
# <body>
#
# <h1>Did you know that climate change causes lung cancer?</h1>
# <p>It's surprising that according to the American Lung Association, rising temperatures, wildfires and poor air quality all lead to an increase in the prevalence of lung cancer.</p>
#
# <h1> But what can you do to solve this issue? </h1>
#
# <h1> Let's start with a quiz about lung cancer. See how much you know!</h1>
#
# </body>
# </html>

# %%
# %%js
# // Define the quiz object with questions as keys and answers as values
# const quiz = {
#   "Is lung the leading cancer killer of both men and women in the US?": "yes",
#   "How many people in the US are currently living with lung cancer? It's in the 100,000s": "400,000",
#   "81% of people living with lung cancer are above which age?": "60",
#   "What is the survival rate of lung cancer? It's really small! (no percent sign)": "17",
#   "Climate change could be irreversible by what year? We don't have much time left!": "2030",
# };
#
# // Function to administer the quiz
# function runQuiz() {
#   const totalQuestions = Object.keys(quiz).length;
#   const correctAnswers = Object.values(quiz);
#   let score = 0;
#
#   let i = 1;
#   for (const [question, correctAnswer] of Object.entries(quiz)) {
#     console.log(`\nQuestion ${i}: ${question}`);
#     const userAnswer = prompt("Your answer: ").trim().toLowerCase();
#
#     if (userAnswer === correctAnswer) {
#       console.log("Correct!");
#       score++;
#     } else {
#       console.log(`Incorrect! The correct answer is: ${correctAnswer}`);
#     }
#
#     i++;
#   }
#
#   // Calculate the score as a percentage and provide the total correct answers
#   const percentageScore = (score / totalQuestions) * 100;
#   console.log("\nQuiz completed!");
#   console.log(`Congrats, you scored ${percentageScore.toFixed(2)}%.`);
#   console.log(`You answered ${score} out of ${totalQuestions} questions correctly.`);
# }
#
# // Run the quiz
# runQuiz();

# %%
# %%html
# <html>
# <head>
#   <style>
#     #myDiv {
#       border: 5px outset rgb(44, 0, 82);
#       background-color: rgb(222, 173, 255);
#       text-align: center;
#             }
#   </style>
# </head>
# <body>
#   <div id="myDiv">
#     <p style="color: rgb(52, 0, 120);">
#       Lung Cancer is a disease that affects so many people in the United States today. As we saw on the quiz, this disease is very prominent and takes the lives of many. Here are some links to learn more about the disease!
#     </p>
#     <button type="button"><a href="https://www.cdc.gov/cancer/lung/basic_info/what-is-lung-cancer.htm">CDC</a></button>
#     <button type="button"><a href="https://www.cancer.org/cancer/types/lung-cancer/about/what-is.html">American Cancer Society</a></button>
#     <button type="button"><a href="https://www.mayoclinic.org/diseases-conditions/lung-cancer/symptoms-causes/syc-20374620">Mayo Clinic</a></button>
#     <button type="button"><a href="https://my.clevelandclinic.org/health/diseases/4375-lung-cancer">Cleveland Clinic</a></button>
#   </div>
# </body>
# </html>
# Out:
# <html>
# <head>
#   <style>
#     #myDiv {
#       border: 5px outset rgb(44, 0, 82);
#       background-color: rgb(222, 173, 255);
#       text-align: center;
#             }
#   </style>
# </head>
# <body>
#   <div id="myDiv">
#     <p style="color: rgb(52, 0, 120);">
#       Lung Cancer is a disease that affects so many people in the United States today. As we saw on the quiz, this disease is very prominent and takes the lives of many. Here are some links to learn more about the disease!
#     </p>
#     <button type="button"><a href="https://www.cdc.gov/cancer/lung/basic_info/what-is-lung-cancer.htm">CDC</a></button>
#     <button type="button"><a href="https://www.cancer.org/cancer/types/lung-cancer/about/what-is.html">American Cancer Society</a></button>
#     <button type="button"><a href="https://www.mayoclinic.org/diseases-conditions/lung-cancer/symptoms-causes/syc-20374620">Mayo Clinic</a></button>
# ...

# %% [markdown]
# ![1000_F_430352470_6HBeZpgA2kzVpYFiEozyNqWJdgrSxWau.jpg](attachment:1000_F_430352470_6HBeZpgA2kzVpYFiEozyNqWJdgrSxWau.jpg)

# %%
# %%html
# <!-- html code goes here (make sure to run) -->
#
# <!-- put your HTML code in this cell, Make sure to press the Run button to see your results below -->
# <head>
# <style>
# .myDiv {
#   border: 5px outset rgb(0, 101, 77);
#   background-color: rgb(137, 203, 141);
#   text-align: center;
# }
# </style>
# </head>
# <body>
#
# <div class="myDiv">
#   <p> <p style="color:rgb(52, 0, 120);"> Climate change is the process of our earth changing. The temperatures are rising around 2 C per year! This is a lot and can lead to detrimental effects in our enviornment. Here are some more links to learn about climate change and what it is.</p>
#
#   <button type="button"><a href="https://www.un.org/en/climatechange/what-is-climate-change">What is climate change?</a> </button>
#   <button type="button"><a href="https://www.worldwildlife.org/threats/effects-of-climate-change">How does climate change impact the environment?</a> </button>
#   <button type="button"><a href="https://www.nps.gov/articles/000/wildlife-climateimpact.htm">Climate change and wildlife</a> </button>
#   <button type="button"><a href="https://carnegieendowment.org/2023/01/04/economic-development-in-era-of-climate-change-pub-88690">Climate change and the economy</a> </button>
# <head>
#   <style>
# Out:
# <!-- html code goes here (make sure to run) -->
#
# <!-- put your HTML code in this cell, Make sure to press the Run button to see your results below -->
# <head>
# <style>
# .myDiv {
#   border: 5px outset rgb(0, 101, 77);
#   background-color: rgb(137, 203, 141);
#   text-align: center;
# }
# </style>
# </head>
# <body>
#
# <div class="myDiv">
#   <p> <p style="color:rgb(52, 0, 120);"> Climate change is the process of our earth changing. The temperatures are rising around 2 C per year! This is a lot and can lead to detrimental effects in our enviornment. Here are some more links to learn about climate change and what it is.</p>
#
#   <button type="button"><a href="https://www.un.org/en/climatechange/what-is-climate-change">What is climate change?</a> </button>
#   <button type="button"><a href="https://www.worldwildlife.org/threats/effects-of-climate-change">How does climate change impact the environment?</a> </button>
# ...

# %%
# %%html
# <html>
# <head>
#   <title>Interactive Climate Change Page</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       text-align: center;
#     }
#     p {
#       font-size: 18px;
#     }
#     button {
#       color: #b46060;
#       padding: 10px 20px;
#       cursor: pointer;
#     }
#   </style>
# </head>
# <body>
#   <h1>What is climate change?</h1>
#   <p id="climate-info">Climate change is a global issue with serious consequences.</p>
#   <button id="change-info">Next</button>
#
#   <script>
#     const infoElement = document.getElementById("climate-info");
#     const changeButton = document.getElementById("change-info");
#
#     changeButton.addEventListener("click", function () {
#       if (infoElement.innerHTML === "Climate change is a global issue with serious consequences.") {
#         infoElement.innerHTML = "It's not only killing our planet but also the species in it. Around 1 million species are on the brink of extinction due to climate change.";
#       } else {
#         infoElement.innerHTML = "Climate change is a global issue with serious consequences.";
#       }
#     });
#   </script>
#
# </body>
# </html>
# Out:
# <html>
# <head>
#   <title>Interactive Climate Change Page</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       text-align: center;
#     }
#     p {
#       font-size: 18px;
#     }
#     button {
#       color: #b46060;
#       padding: 10px 20px;
#       cursor: pointer;
#     }
#   </style>
# </head>
# <body>
#   <h1>What is climate change?</h1>
#   <p id="climate-info">Climate change is a global issue with serious consequences.</p>
#   <button id="change-info">Next</button>
#
#   <script>
#     const infoElement = document.getElementById("climate-info");
#     const changeButton = document.getElementById("change-info");
#
#     changeButton.addEventListener("click", function () {
#       if (infoElement.innerHTML === "Climate change is a global issue with serious consequences.") {
# ...
